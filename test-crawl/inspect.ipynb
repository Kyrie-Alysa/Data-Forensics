# %% [markdown]
# # Inspection

# %%
import pandas as pd

# %%
# Read in csv file
df = pd.read_csv('rent_a_hacker.csv')

# %%
df
# Out:
#                                                  Text
# 0   Rent-A-HackerExperienced hacker offering his s...
# 1   (Illegal) Hacking and social engineering is my...
# 2   I have worked for other people before, now i a...
# 3                                             Prices:
# 4   I am not doing this to make a few bucks here a...
# 5   I am a professional computer expert who could ...
# 6   So stop reading if you don't have a serious pr...
# 7   Prices depend a lot on the problem you want me...
# 8           You can pay me anonymously using Bitcoin.
# 9                                   Technical skills:
# 10                     - Web (HTML, PHP, SQL, APACHE)
# 11                         - C/C++, Assembler, Delphi
# 12  - 0day Exploits, Highly personalized trojans, ...
# 13  - Spear Phishing Attacks to get accounts from ...
# 14  - Basically anything a hacker needs to be succ...
# 15  - Anonymity: no one will ever find out who i a...
# ...
